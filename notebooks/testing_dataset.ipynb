# %% [markdown]
# # Create small dataset for testing

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy

# %%
im1 = Image.open("../test/data/1.tiff")
im2 = Image.open("../test/data/2.tiff")

# %%
plt.imshow(numpy.array(im1))

# %%
plt.imshow(numpy.array(im2))

# %%
im1.size
# Out:
# (104, 29)

# %%
im1.n_frames
# Out:
# 8
